# %% [markdown]
# # Machine Learning Pipeline - Feature Selection
#
# En esta sección, implementaremos dos métodos distintos para la selección de características en nuestro modelo:
#
# - LGBMClassifier con SelectFromModel: Utiliza la importancia de las características de LightGBM para seleccionar automáticamente las más relevantes.
#
# - SelectKBest con chi-cuadrado: Filtra las mejores características en función de su relación con la variable objetivo.
#
# Estos métodos nos ayudarán a reducir la dimensionalidad del conjunto de datos, eliminar información redundante y mejorar la interpretabilidad del modelo.

# %%
# to handle datasets
import pandas as pd
import numpy as np
# for plotting
import matplotlib.pyplot as plt
# to build the models
from sklearn.linear_model import Lasso, Ridge
from sklearn.feature_selection import SelectFromModel
# to visualise al the columns in the dataframe
pd.pandas.set_option('display.max_columns', None)

# %%
# cargar el conjunto de entrenamiento y prueba con las engineered variables

# Nosotros construimos y guardamos estos conjuntos de datos en la lección anterior.
# Si no lo has hecho, revisa el NOTEBOOK anterior para saber cómo crear estos conjuntos de datos.
X_train = pd.read_parquet('../data/xtrain_postprocess.parquet')
X_test= pd.read_parquet('../data/xtest_postprocess.parquet')

X_train.head()
# Out:
#    24M_MONTO  24M_TASA      EDAD  MARCA_LABORAL  PROPENSION  COMPETITIVIDAD  \
# 0   1.291955 -0.048104 -0.635266       0.430569   -1.435378        1.023889
# 1   0.003182 -0.048104  0.474877       0.430569    0.696681       -0.976669
# 2   1.203497  0.651609  0.050392      -1.273593    0.696681        1.023889
# 3  -2.807544 -0.735512  1.644850       0.430569    0.696681       -0.976669
# 4   1.360376  0.651609 -0.855836      -0.421512    0.696681       -0.976669
#
#    PRINCIPALIDAD_CONSUMO  ULTIMA_AGRUPACION  RANGO_RCI  ESTADO_CIVIL  \
# 0               0.047958           0.573193   1.131137      0.738081
# 1              -1.015682           1.881238  -0.567665     -1.354865
# 2               0.047958          -0.734852  -0.567665     -1.354865
# 3               1.111599          -0.734852   1.980538     -1.354865
# 4               0.047958          -0.734852  -0.567665      0.738081
#
#      GENERO  veces_acepto_producto  tiempo_desde_ultima_conversion  \
# 0  1.027575                0.00000                             0.0
# 1 -0.973165                0.00000                             0.0
# 2 -0.973165               -0.02628                             0.0
# 3  1.027575                0.00000                             0.0
# 4 -0.973165               -0.02628                             0.0
#
#    tiempo_desde_ultima_negacion  intentos_totales  meses_gestionados  \
# 0                      0.082951     -2.599419e-16      -9.124915e-16
# 1                      0.082951     -2.599419e-16      -9.124915e-16
# 2                      0.082951     -4.494340e-01       3.207781e+00
# 3                      0.082951     -2.599419e-16      -9.124915e-16
# 4                      0.082951     -7.421025e-01      -9.017157e-01
#
#    dias_ultima_gestion  ultima_gestion  veces_sin_respuesta  \
# 0             0.144654        0.612022             0.067193
# 1             0.144654        0.612022             0.067193
# 2             0.144654       -1.726393             0.067193
# 3             0.144654        0.612022             0.067193
# 4             0.144654       -1.726393             0.067193
#
#    veces_solicitud_seguimiento  promedio_dias_entre_gestiones  \
# 0                 7.642187e-17                       0.322698
# 1                 7.642187e-17                       0.322698
# 2                -2.363434e-01                       0.322698
# 3                 7.642187e-17                       0.322698
# 4                -2.363434e-01                       0.322698
#
#    max_intentos_en_un_mes  veces_respuesta_positiva  veces_respuesta_negativa  \
# 0            2.800129e-16              1.185844e-16                  0.536515
# 1            2.800129e-16              1.185844e-16                  0.536515
# 2           -4.853716e-01             -2.580264e-01                 -1.863879
# 3            2.800129e-16              1.185844e-16                  0.536515
# 4           -6.430049e-01             -2.580264e-01                 -1.863879
#
#    _merge_variables  Bancos_PLD_Total  Cajas_PLD_Total  Retail_PLD_Total  \
# 0         -0.627359         -0.412530         -0.21688         -0.250451
# 1         -0.627359         -0.412530         -0.21688         -0.250451
# 2          1.593984         -0.412530         -0.21688         -0.250451
# 3         -0.627359          2.424065         -0.21688         -0.250451
# 4          1.593984         -0.412530         -0.21688         -0.250451
#
#    PLD_Total  Bancos_TC_Total  Retail_TC_Total  TC_Total  \
# 0  -0.366340         1.778780        -0.553423  2.723939
# 1  -0.366340        -0.562183        -0.553423 -0.391352
# 2  -0.366340         1.778780         1.806935  0.434225
# 3   2.828669        -0.562183        -0.553423 -0.391352
# 4  -0.366340         1.778780        -0.553423 -0.362580
#
#    Bancos_PLD_Entidades  Cajas_PLD_Entidades  Retail_PLD_Entidades  \
# 0             -0.405492            -0.215308             -0.245543
# 1             -0.405492            -0.215308             -0.245543
# 2             -0.405492            -0.215308             -0.245543
# 3              2.298049            -0.215308             -0.245543
# 4             -0.405492            -0.215308             -0.245543
#
#    PLD_Entidades  Bancos_TC_Entidades  Retail_TC_Entidades  TC_Entidades  \
# 0      -0.526079             5.032017             -0.50462      3.082557
# 1      -0.526079            -0.519054             -0.50462     -0.714007
# 2      -0.526079             3.181660              1.27419      3.082557
# 3       1.520659            -0.519054             -0.50462     -0.714007
# 4      -0.526079             1.331303             -0.50462      0.551514
#
#    TC_Entidades_Mas3  Tiene_Deuda_PLD  CANTIDAD_CELULARES  \
# 0          -0.070643        -0.553611            1.874272
# 1          -0.070643        -0.553611           -0.915133
# 2          -0.070643        -0.553611           -0.915133
# 3          -0.070643         1.806322            1.874272
# 4          -0.070643        -0.553611            0.944471
#
#    veces_acepto_producto_na  tiempo_desde_ultima_conversion_na  \
# 0                  0.627359                           0.007422
# 1                  0.627359                           0.007422
# 2                 -1.593984                           0.007422
# 3                  0.627359                           0.007422
# 4                 -1.593984                           0.007422
#
#    tiempo_desde_ultima_negacion_na  intentos_totales_na  meses_gestionados_na  \
# 0                         0.250199             0.627359              0.627359
# 1                         0.250199             0.627359              0.627359
# 2                         0.250199            -1.593984             -1.593984
# 3                         0.250199             0.627359              0.627359
# 4                         0.250199            -1.593984             -1.593984
#
#    dias_ultima_gestion_na  veces_sin_respuesta_na  \
# 0                0.627359                0.627359
# 1                0.627359                0.627359
# 2               -1.593984               -1.593984
# 3                0.627359                0.627359
# 4               -1.593984               -1.593984
#
#    veces_solicitud_seguimiento_na  promedio_dias_entre_gestiones_na  \
# 0                        0.627359                          0.627359
# 1                        0.627359                          0.627359
# 2                       -1.593984                         -1.593984
# 3                        0.627359                          0.627359
# 4                       -1.593984                         -1.593984
#
#    max_intentos_en_un_mes_na  veces_respuesta_positiva_na  \
# 0                   0.627359                     0.627359
# 1                   0.627359                     0.627359
# 2                  -1.593984                    -1.593984
# 3                   0.627359                     0.627359
# 4                  -1.593984                    -1.593984
#
#    veces_respuesta_negativa_na  ESTADO_TASA  ESTADO_OFERTA  NUEVA_OFERTA
# 0                     0.627359    -0.771717      -0.770394     -0.591161
# 1                     0.627359    -0.002441       0.358935     -0.591161
# 2                    -1.593984    -0.771717       0.358935     -0.591161
# 3                     0.627359    -0.771717       0.358935     -0.591161
# 4                    -1.593984    -0.771717      -0.770394     -0.591161

# %%
# Cargar el objetivo (recuerda que el objetivo está transformado logarítmicamente).
y_train = pd.read_parquet('../data/ytrain_postprocess.parquet')
y_test = pd.read_parquet('../data/ytest_postprocess.parquet')

y_train.head()
# Out:
#         target
# 669583     0.0
# 661308     0.0
# 743633     0.0
# 148963     0.0
# 557373     0.0

# %% [markdown]
# # 1️⃣ Selección de características con LGBMClassifier
# El algoritmo LightGBM es un modelo basado en árboles de decisión optimizado para velocidad y eficiencia. Su importancia de características puede ser utilizada junto con SelectFromModel para eliminar variables menos relevantes.

# %%
from sklearn.feature_selection import SelectFromModel
from lightgbm import LGBMClassifier  # O puedes usar XGBClassifier

# Modelo LGBM con manejo de desbalanceo
model = LGBMClassifier(n_estimators=500, importance_type='gain', scale_pos_weight=10, random_state=0)

# Selector de variables con LGBM
selector = SelectFromModel(model, threshold="mean", prefit=False)

# Entrenar el modelo y seleccionar características
selector.fit(X_train, y_train)

# Obtener las variables seleccionadas
selected_features = X_train.columns[selector.get_support()]
print("📌 Variables seleccionadas:", selected_features.tolist())
# Out:
# D:\anaconda3\envs\mlops_d11_p310_M1\lib\site-packages\sklearn\preprocessing\_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\anaconda3\envs\mlops_d11_p310_M1\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 794, number of negative: 689153
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.025673 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1236
# [LightGBM] [Info] Number of data points in the train set: 689947, number of used features: 57
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001151 -> initscore=-6.766135
# [LightGBM] [Info] Start training from score -6.766135
# 📌 Variables seleccionadas: ['24M_MONTO', 'EDAD', 'PRINCIPALIDAD_CONSUMO', 'ULTIMA_AGRUPACION', 'intentos_totales', 'max_intentos_en_un_mes', 'veces_respuesta_positiva']

# %%
['24M_MONTO', 'EDAD', 'PRINCIPALIDAD_CONSUMO', 
 'ULTIMA_AGRUPACION', 'intentos_totales',
 'max_intentos_en_un_mes', 'veces_respuesta_positiva']

# %% [markdown]
# # 2️⃣ Selección de características con SelectKBest
# SelectKBest selecciona las k mejores características basándose en pruebas estadísticas. Para problemas de clasificación, podemos usar chi-cuadrado para evaluar la relación entre cada variable y la variable objetivo.

# %%
from sklearn.feature_selection import mutual_info_classif, SelectKBest

# Selección de variables basada en información mutua
selector = SelectKBest(score_func=mutual_info_classif, k=10)  # Selecciona las 10 mejores
X_new = selector.fit_transform(X_train, y_train)

# Obtener las variables seleccionadas
selected_features = X_train.columns[selector.get_support()]
print("📌 Variables seleccionadas:", selected_features.tolist())
# Out:
# D:\anaconda3\envs\mlops_d11_p310_M1\lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 📌 Variables seleccionadas: ['COMPETITIVIDAD', 'GENERO', 'veces_respuesta_negativa', 'Bancos_TC_Total', 'Retail_TC_Total', 'PLD_Entidades', 'Tiene_Deuda_PLD', 'dias_ultima_gestion_na', 'veces_solicitud_seguimiento_na', 'NUEVA_OFERTA']

# %%
['COMPETITIVIDAD', 'GENERO', 'veces_respuesta_negativa', 
 'Bancos_TC_Total', 'Retail_TC_Total', 'PLD_Entidades', 
 'Tiene_Deuda_PLD', 'dias_ultima_gestion_na',
 'veces_solicitud_seguimiento_na', 'NUEVA_OFERTA']
